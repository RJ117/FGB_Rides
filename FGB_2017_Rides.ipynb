# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df =  pd.read_csv('C:/Users/RJ/Documents/FGB/2017-fordgobike-tripdata.csv')

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1         78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2         45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3         62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4         43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
#
#    start_station_id                                 start_station_name  \
# 0                74                              Laguna St at Hayes St
# 1               284  Yerba Buena Center for the Arts (Howard St at ...
# 2               245                             Downtown Berkeley BART
# 3                60                               8th St at Ringold St
# 4               239                      Bancroft Way at Telegraph Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519700 entries, 0 to 519699
# Data columns (total 15 columns):
# duration_sec               519700 non-null int64
# start_time                 519700 non-null object
# end_time                   519700 non-null object
# start_station_id           519700 non-null int64
# start_station_name         519700 non-null object
# start_station_latitude     519700 non-null float64
# start_station_longitude    519700 non-null float64
# end_station_id             519700 non-null int64
# end_station_name           519700 non-null object
# end_station_latitude       519700 non-null float64
# end_station_longitude      519700 non-null float64
# bike_id                    519700 non-null int64
# user_type                  519700 non-null object
# member_birth_year          453159 non-null float64
# member_gender              453238 non-null object
# dtypes: float64(5), int64(4), object(6)
# memory usage: 59.5+ MB

# %%
df.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender'],
#       dtype='object')

# %%
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  519700.000000     519700.000000           519700.000000
# mean     1099.009521         95.034245               37.771653
# std      3444.146451         86.083078                0.086305
# min        61.000000          3.000000               37.317298
# 25%       382.000000         24.000000               37.773492
# 50%       596.000000         67.000000               37.783521
# 75%       938.000000        139.000000               37.795392
# max     86369.000000        340.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            519700.000000   519700.000000         519700.000000
# mean               -122.363927       92.184041             37.771844
# std                   0.105573       84.969491              0.086224
# min                -122.444293        3.000000             37.317298
# ...

# %%
sns.set_style('whitegrid')

# %% [markdown]
# <H2>Location</h2>

# %% [markdown]
# <h3>Start Time</h3>
# <br>
# Heatmap shows number of bikes for the docks in the Bay Area.

# %%
df[['member_birth_year', 'start_time']]
sns.distplot(df['start_time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-5dd40127d4f6> in <module>()
#       1 df[['member_birth_year', 'start_time']]
# ----> 2 sns.distplot(df['start_time'])
#
# ~\Anaconda3.1\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     189             line, = ax.plot(0, a.mean())
#     190         else:
# --> 191             line, = ax.plot(a.mean(), 0)
#     192         color = line.get_color()
#     193         line.remove()
#
# ~\Anaconda3.1\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      80             ret = ret.dtype.type(ret / rcount)
#      81     else:
# ---> 82         ret = ret / rcount
#      83
#      84     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# Purple indicates data properly collected.  Yellow indicates missing or incomplete data.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.countplot(x='start_station_name',data=df)

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(pd.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7cd17f86a237> in <module>()
# ----> 1 sns.heatmap(pd.corr(),annot=True)
#
# AttributeError: module 'pandas' has no attribute 'corr'

# %%
sns.countplot(x='end_station_name',data=df)

# %% [markdown]
# <b><h2>User Type</b></h2>
# <br>
# Breaks down the number of subscriber verses customer.
# <br><br>
# Concentration of subscribers may need to shift to developing methods to attract single riders to increase revenue.
# <br><br>
# <i>Please note further breakdown of pricing is not shown: 'Customer has three pricing tiers: Single Ride, All-Day and  3-day.  Subscriber has two pricing structures: Low-Income which 5 dollars for one year membership or 150 dollars which can be paid in 10 monthly installments of 15 dollars per month.</i>

# %%
sns.countplot(x='user_type',data=df)

# %%
sns.distplot(df['user_type'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2990654c4b3a> in <module>()
# ----> 1 sns.distplot(df['user_type'])
#
# ~\Anaconda3.1\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     189             line, = ax.plot(0, a.mean())
#     190         else:
# --> 191             line, = ax.plot(a.mean(), 0)
#     192         color = line.get_color()
#     193         line.remove()
#
# ~\Anaconda3.1\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      80             ret = ret.dtype.type(ret / rcount)
#      81     else:
# ---> 82         ret = ret / rcount
#      83
#      84     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# <b><h2>Age</h2></b>
# <br>
# The bar graph shows majority of riders are in the range of late 1980 to mid 1990's.
# <br>
# <br>
# Ford Go Bike Plus has the potential to attract more riders from in a wider range.

# %%
df['member_birth_year'].hist(bins=35,figsize=(25,15))

# %%
import plotly.plotly as py
import plotly.graph_objs as go

values = list(range(1899, 2001))

trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename='basic_pie_chart')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a56ea2a8a4eb> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import plotly.graph_objs as go
#       3
#       4 values = list(range(1899, 2001))
#       5
#
# ModuleNotFoundError: No module named 'plotly'

# %%
def avg('member_birth_year')

# %% [markdown]
# <h2>Gender</h2>

# %%
sns.countplot(x='member_gender',data=df)

# %% [markdown]
# Stations

# %%
df['start_station_name'].hist(bins=40,figsize=(25,15))

# %%
df.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender'],
#       dtype='object')

# %%
df
# Out:
#         duration_sec                start_time                  end_time  \
# 0              80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1              78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2              45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3              62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4              43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
# 5               9226  2017-12-31 22:51:00.9180  2018-01-01 01:24:47.1660
# 6               4507  2017-12-31 23:49:28.4220  2018-01-01 01:04:35.6190
# 7               4334  2017-12-31 23:46:37.1960  2018-01-01 00:58:51.2110
# 8               4150  2017-12-31 23:37:07.5480  2018-01-01 00:46:18.3080
# 9               4238  2017-12-31 23:35:38.1450  2018-01-01 00:46:17.0530
# 10              3292  2017-12-31 23:46:32.4030  2018-01-01 00:41:24.6050
# 11              3177  2017-12-31 23:48:11.7570  2018-01-01 00:41:09.5810
# ...

# %%
sns.pairplot(df,hue='member_birth_year')
